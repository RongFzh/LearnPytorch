# %%
print('fast ai vision.image')
# Out:
# fast ai vision.image

# %%
from fastai.vision import *

# %%
img = open_image('/home/rong/图片/cat_sample.png')

# %%
pwd
# Out:
# '/home/rong/PycharmProjects/PyTorchTutorals'

# %%
img
# Out:
# Image (3, 500, 394)

# %%
img.show()

# %%
_,axs = plt.subplots(1,4,figsize=(12,4))
for i,ax in enumerate(axs): img.show(ax=ax, title=f'Copy {i+1}')

# %%
img.data.shape
# Out:
# torch.Size([3, 500, 394])
